# %%
import nltk
from sklearn.datasets import fetch_20newsgroups
news = fetch_20newsgroups(subset='all')
print len(news.data)
print len(news.target_names)
print news.target_names

# %%
import matplotlib.pyplot as plt

# %%
x = [2, 4, 6]
y = [1, 3, 5]
plt.plot(x, y)
plt.show()

# %%
year = [1960, 1970, 1980, 1990, 2000, 2010, 2020]
pop_pakistan = [44.91, 58.09, 78.07, 107.7, 138.5, 170.6, 220]
#pop_india = [449.48, 553.57, 696.783, 870.133, 1000.4, 1309.1]
#plt.plot(year, pop_pakistan, color='g')
plt.plot( year, pop_pakistan, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
#plt.plot(year, pop_india, color='orange')
plt.xlabel('Year')
plt.ylabel('Population in million')
plt.title('Pakistan  Population till 2020')
plt.show()

# %%
import numpy as np
import pandas as pd
price = [27000,36000,30500,49500,37900,40500,45000,37000,66000,38500,66000,69000,83800,40750,88500,42000,61000,60500,90000]
plotsize = [1700,2880,3000,3060,3185,3300,3450,3600,3880,4000,4160,4160,4800,5200,5500,5850,6360,6650,7200]
plt.plot( plotsize, price, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.ylabel(' Price of PLot')
plt.xlabel('PlotSize')
plt.title('Plot Size and Price')
plt.show()
